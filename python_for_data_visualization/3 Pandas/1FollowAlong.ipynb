# %%
import pandas as pd
import numpy as np

# %%
# Approach 1 List
car_loans = [[1, 34689.96, 687.23, 202.93, 484.30, 34205.66, 60, 0.0702, 'Toyota Sienna'], 
             [2, 34205.65, 687.23, 200.01, 487.13, 337185.53, 60, 0.0702, 'Toyota Sienna'],
             [3, 33718.52, 687.23, 197.25, 489.98, 32338.55, 60, 0.0702, 'Toyota Sienna'],
             [4, 33228.55, 687.23, 194.38, 492.85, 32735.70, 60, 0.0702, 'Toyota Sienna'],
             [5, 32735.70, 687.23, 191.50, 495.73, 32239.97, 60, 0.0702, 'Toyota Sienna']]
col_names = ['Month',
            'Starting Balance',
            'Repayment',
            'Interest Paid',
            'Principal Paid',
            'New Balance',
            'Term',
            'Interest Rate',
            'Car Type']

# %%
df = pd.DataFrame(data = car_loans, columns=col_names )

# %%
df
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.65     687.23         200.01          487.13
# 2      3          33718.52     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
#
#    New Balance  Term  Interest Rate       Car Type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1    337185.53    60         0.0702  Toyota Sienna
# 2     32338.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna

# %%
car_loans = np.array([
            [1, 34689.96, 687.23, 202.93, 484.30, 34205.66, 60, 0.0702, 'Toyota Sienna'], 
             [2, 34205.65, 687.23, 200.01, 487.13, 337185.53, 60, 0.0702, 'Toyota Sienna'],
             [3, 33718.52, 687.23, 197.25, 489.98, 32338.55, 60, 0.0702, 'Toyota Sienna'],
             [4, 33228.55, 687.23, 194.38, 492.85, 32735.70, 60, 0.0702, 'Toyota Sienna'],
             [5, 32735.70, 687.23, 191.50, 495.73, 32239.97, 60, 0.0702, 'Toyota Sienna']
            ])

col_names = ['Month',
            'Starting Balance',
            'Repayment',
            'Interest Paid',
            'Principal Paid',
            'New Balance',
            'Term',
            'Interest Rate',
            'Car Type']

# %%
df = pd.DataFrame(data = car_loans, columns=col_names)

# %%
df
# Out:
#   Month Starting Balance Repayment Interest Paid Principal Paid New Balance  \
# 0     1         34689.96    687.23        202.93          484.3    34205.66
# 1     2         34205.65    687.23        200.01         487.13   337185.53
# 2     3         33718.52    687.23        197.25         489.98    32338.55
# 3     4         33228.55    687.23        194.38         492.85     32735.7
# 4     5          32735.7    687.23         191.5         495.73    32239.97
#
#   Term Interest Rate       Car Type
# 0   60        0.0702  Toyota Sienna
# 1   60        0.0702  Toyota Sienna
# 2   60        0.0702  Toyota Sienna
# 3   60        0.0702  Toyota Sienna
# 4   60        0.0702  Toyota Sienna

# %%
car_loans = [[1, 34689.96, 687.23, 202.93, 484.30, 34205.66, 60, 0.0702, 'Toyota Sienna'], 
             [2, 34205.65, 687.23, 200.01, 487.13, 337185.53, 60, 0.0702, 'Toyota Sienna'],
             [3, 33718.52, 687.23, 197.25, 489.98, 32338.55, 60, 0.0702, 'Toyota Sienna'],
             [4, 33228.55, 687.23, 194.38, 492.85, 32735.70, 60, 0.0702, 'Toyota Sienna'],
             [5, 32735.70, 687.23, 191.50, 495.73, 32239.97, 60, 0.0702, 'Toyota Sienna'],
             [35, 32735.70, 687.23, 191.50, 495.73, 32239.97, 60, 0.0702, 'Toyota Sienna'],
             [36, 34689.96, 687.23, 202.93, 484.30, 34205.66, 60, 0.0702, 'Toyota Sienna'], 
             [37, 34205.65, 687.23, 200.01, 487.13, 337185.53, 60, 0.0702, 'Toyota Sienna'],
             [38, 33718.52, 687.23, 197.25, 489.98, 32338.55, 60, 0.0702, 'Toyota Sienna'],
             [39, 33228.55, 687.23, 194.38, 492.85, 32735.70, 60, 0.0702, 'Toyota Sienna'],
             [40, 32735.70, 687.23, 191.50, 495.73, 32239.97, 60, 0.0702, 'Toyota Sienna'],
             [41, 34689.96, 687.23, 202.93, 484.30, 34205.66, 60, 0.0702, 'Toyota Sienna'], 
             [42, 34205.65, 687.23, 200.01, 487.13, 337185.53, 60, 0.0702, 'Toyota Sienna'],
             [43, 33718.52, 687.23, 197.25, 489.98, 32338.55, 60, 0.0702, 'Toyota Sienna'],
             [44, 33228.55, 687.23, 194.38, 492.85, 32735.70, 60, 0.0702, 'Toyota Sienna'],
             [45, 32735.70, 687.23, 191.50, 495.73, 32239.97, 60, 0.0702, 'Toyota Sienna'],
             [46, 34689.96, 687.23, 202.93, 484.30, 34205.66, 60, 0.0702, 'Toyota Sienna'], 
             [47, 34205.65, 687.23, 200.01, 487.13, 337185.53, 60, 0.0702, 'Toyota Sienna'],
             [48, 33718.52, 687.23, 197.25, 489.98, 32338.55, 60, 0.0702, 'Toyota Sienna'],
             [49, 33228.55, 687.23, 194.38, 492.85, 32735.70, 60, 0.0702, 'Toyota Sienna'],
             [50, 32735.70, 687.23, 191.50, 495.73, 32239.97, 60, 0.0702, 'Toyota Sienna'],
             [51, 34689.96, 687.23, 202.93, 484.30, 34205.66, 60, 0.0702, 'Toyota Sienna'], 
             [52, 34205.65, 687.23, 200.01, 487.13, 337185.53, 60, 0.0702, 'Toyota Sienna'],
             [53, 33718.52, 687.23, 197.25, 489.98, 32338.55, 60, 0.0702, 'Toyota Sienna'],
             [54, 33228.55, 687.23, 194.38, 492.85, 32735.70, 60, 0.0702, 'Toyota Sienna'],
             [55, 32735.70, 687.23, 191.50, 495.73, 32239.97, 60, 0.0702, 'Toyota Sienna'],
             [56, 34689.96, 687.23, 202.93, 484.30, 34205.66, 60, 0.0702, 'Toyota Sienna'], 
             [57, 34205.65, 687.23, 200.01, 487.13, 337185.53, 60, 0.0702, 'Toyota Sienna'],
             [58, 33718.52, 687.23, 197.25, 489.98, 32338.55, 60, 0.0702, 'Toyota Sienna'],
             [59, 33228.55, 687.23, 194.38, 492.85, 32735.70, 60, 0.0702, 'Toyota Sienna'],
             [60, 32735.70, 687.23, 191.50, 495.73, 32239.97, 60, 0.0702, 'Toyota Sienna']
             ]
col_names = ['Month',
            'Starting Balance',
            'Repayment',
            'Interest Paid',
            'Principal Paid',
            'New Balance',
            'Term',
            'Interest Rate',
            'Car Type']

# %%
df = pd.DataFrame(data = car_loans, columns = col_names)

# %%
df
# Out:
#     Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0       1          34689.96     687.23         202.93          484.30
# 1       2          34205.65     687.23         200.01          487.13
# 2       3          33718.52     687.23         197.25          489.98
# 3       4          33228.55     687.23         194.38          492.85
# 4       5          32735.70     687.23         191.50          495.73
# 5       6          34689.96     687.23         202.93          484.30
# 6       7          34205.65     687.23         200.01          487.13
# 7       8          33718.52     687.23         197.25          489.98
# 8       9          33228.55     687.23         194.38          492.85
# 9      10          32735.70     687.23         191.50          495.73
# 10     11          34689.96     687.23         202.93          484.30
# 11     12          34205.65     687.23         200.01          487.13
# ...

# %% [markdown]
# # Load Sample Data

# %%
# Load car loan data from a csv file
filename = 'data/car_financing.csv'
df = pd.read_csv(filename)

# %%
df
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0        1          34689.96     687.23         202.93          484.30
# 1        2          34205.66     687.23         200.10          487.13
# 2        3          33718.53     687.23         197.25          489.98
# 3        4          33228.55     687.23         194.38          492.85
# 4        5          32735.70     687.23         191.50          495.73
# ..     ...               ...        ...            ...             ...
# 403     56           3951.11     796.01           9.54          786.47
# 404     57           3164.64     796.01           7.64          788.37
# 405     58           2376.27     796.01           5.74          790.27
# 406     59           1586.00     796.01           3.83          792.18
# 407     60            793.82     796.01           1.91          794.10
#
#      New Balance  term  interest_rate       car_type
# 0       34205.66    60         0.0702  Toyota Sienna
# ...

# %%
filename = 'data/car_financing.xlsx'
df = pd.read_excel(filename)

# %%
df.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna

# %% [markdown]
# # Basic Operations
#  1. Assure that you have correctly loaded the data
#  2. See what kind of data you have
#  3. Check the validity of the data

# %% [markdown]
# ### Viewing the first and last five rows

# %%
df.head()
# Out:
#    Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 0      1          34689.96     687.23         202.93          484.30
# 1      2          34205.66     687.23         200.10          487.13
# 2      3          33718.53     687.23         197.25          489.98
# 3      4          33228.55     687.23         194.38          492.85
# 4      5          32735.70     687.23         191.50          495.73
#
#    New Balance  term  interest_rate       car_type
# 0     34205.66    60         0.0702  Toyota Sienna
# 1     33718.53    60         0.0702  Toyota Sienna
# 2     33228.55    60         0.0702  Toyota Sienna
# 3     32735.70    60         0.0702  Toyota Sienna
# 4     32239.97    60         0.0702  Toyota Sienna

# %%
df.tail()
# Out:
#      Month  Starting Balance  Repayment  Interest Paid  Principal Paid  \
# 403     56           3951.11     796.01           9.54          786.47
# 404     57           3164.64     796.01           7.64          788.37
# 405     58           2376.27     796.01           5.74          790.27
# 406     59           1586.00     796.01           3.83          792.18
# 407     60            793.82     796.01           1.91          794.10
#
#      New Balance  term  interest_rate   car_type
# 403      3164.64    60          0.029  VW Golf R
# 404      2376.27    60          0.029  VW Golf R
# 405      1586.00    60          0.029  VW Golf R
# 406       793.82    60          0.029  VW Golf R
# 407        -0.28    60          0.029  VW Golf R

# %% [markdown]
# ### Check your column data types

# %%
df.dtypes
# Out:
# Month                 int64
# Starting Balance    float64
# Repayment           float64
# Interest Paid       float64
# Principal Paid      float64
# New Balance         float64
# term                  int64
# interest_rate       float64
# car_type             object
# dtype: object

# %%
# Use the shape attribute to get the number of rowns and columns in your dataframe
df.shape
# Out:
# (408, 9)

# %%
# The info method gives the column datatypes + number of non-null values
# Notive that we seem to have 408 non-null values for all but the Interest Paid column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Month             408 non-null    int64
#  1   Starting Balance  408 non-null    float64
#  2   Repayment         408 non-null    float64
#  3   Interest Paid     407 non-null    float64
#  4   Principal Paid    408 non-null    float64
#  5   New Balance       408 non-null    float64
#  6   term              408 non-null    int64
#  7   interest_rate     408 non-null    float64
#  8   car_type          408 non-null    object
# dtypes: float64(6), int64(2), object(1)
# memory usage: 28.8+ KB
